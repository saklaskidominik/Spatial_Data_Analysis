# %% [markdown]
# <h2 style="text-align: center;">Task Set 3</h2>
# <h1 style="text-align: center;">Dependence of process intensity on the value of an accompanying variable</h1>

# %% [markdown]
# #### 1.  Wczytanie potrzebnych pakietów

# %%
library(spatstat)
# Out:
# Ładowanie wymaganego pakietu: spatstat.data
#
# Ładowanie wymaganego pakietu: spatstat.univar
#
# spatstat.univar 3.1-1
#
# Ładowanie wymaganego pakietu: spatstat.geom
#
# spatstat.geom 3.3-4
#
# Ładowanie wymaganego pakietu: spatstat.random
#
# spatstat.random 3.3-2
#
# Ładowanie wymaganego pakietu: spatstat.explore
#
# Ładowanie wymaganego pakietu: nlme
#
# spatstat.explore 3.3-3
#
# Ładowanie wymaganego pakietu: spatstat.model
#
# Ładowanie wymaganego pakietu: rpart
#
# spatstat.model 3.3-3
#
# Ładowanie wymaganego pakietu: spatstat.linnet
#
# spatstat.linnet 3.2-3
#
#
# spatstat 3.3-0
# For an introduction to spatstat, type 'beginner'

# %% [markdown]
# W analizach przestrzennych istotnym zagadnieniem jest wzajemne położenie różnych obiektów, np. złóż
# złota lub obiektów liniowych (uskoków). Można np. zapytać jaka jest odległość obiektów punktowych od
# najbliższego obiektu liniowego.

# %% [markdown]
# #### 2. Wyświetlenie mapy z uskokami
# Wyświetl mapę rozmieszczenia złóż złota (z poprzednich zajęć). Nałóż na nią mapę występowania
# uskoków.

# %%
# Wczytanie danych
data(murchison)
cat("Obiekt `murchison` zawiera następujące dane geologiczne obszaru Murchison:\n")
print(murchison)

# Wydzielenie poszczególnych elementów obiektu
gold <- murchison$gold
faults <- murchison$faults

# Wyświetlenie informacji o złóż złota
cat("\n\nProces punktowy `gold` - lokalizacja złóż złota:\n")
print(gold)

# Wyświetlenie informacji o uskokach
cat("\nElement `faults` - położenie uskoków:\n")
print(faults)

options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Wyświetl mapę rozmieszczenia złóż złota i nałóż na nią mapę występowania uskoków
plot(faults, main = "Mapa lokalizacji złóż złota i uskoków", col = "red", lwd = 2,
     xlab = "Współrzędna X", ylab = "Współrzędna Y")
plot(gold, add = TRUE, col = "gold", pch = 20)
# Out:
# Obiekt `murchison` zawiera następujące dane geologiczne obszaru Murchison:
# List of spatial objects
#
# gold:
# Planar point pattern: 255 points
# window: rectangle = [352782.9, 682589.6] x [6699742, 7101484] metres
#
# faults:
# planar line segment pattern: 3252 line segments
# window: rectangle = [352782.9, 682589.6] x [6699742, 7101484] metres
#
# greenstone:
# window: polygonal boundary
# enclosing rectangle: [352782.9, 681699.6] x [6706467, 7100804] metres
#
#
# Proces punktowy `gold` - lokalizacja złóż złota:
# Planar point pattern: 255 points
# window: rectangle = [352782.9, 682589.6] x [6699742, 7101484] metres
#
# Element `faults` - położenie uskoków:
# planar line segment pattern: 3252 line segments
# window: rectangle = [352782.9, 682589.6] x [6699742, 7101484] metres
# Plot with title "Mapa lokalizacji złóż złota i uskoków"

# %% [markdown]
# #### 3. Mapa odległości od najbliższego uskoku
# Analiza związku występowania złóż złota z siecią uskoków wymaga stworzenia mapy będącej
# funkcją współrzędnej przestrzennej `u(x,y)`. Niech mapą tą będzie mapą `Z(u)` odległości dowolnego
# punktu u od najbliższego uskoku.
# Przekonwertuj informacje zawarte w mapie uskoków geologicznych `(L)` do zmiennej
# stowarzyszonej `(covariate)`, która jest funkcją `Z(u)` lokalizacji przestrzennej `u`.
# $$
# Z(u) = \text{distance from } u \text{ to } L
# $$
#
# Obliczenia te można wykonać używając komendy distmap, która zwraca obraz pikseli zawierający wartości
# `Z(u)` w siatce pikseli `u`.

# %%
# Obliczanie mapy odległości od najbliższego uskoku
faults_distmap <- distmap(faults)

options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Wizualizacja mapy odległości
plot(faults_distmap, main = "Mapa odległości od najbliższego uskoku", xlab = "Współrzędna X", 
     ylab = "Współrzędna Y", col = topo.colors(20))
# Out:
# Plot with title "Mapa odległości od najbliższego uskoku"

# %% [markdown]
# #### 4. Nałożenie rozmieszczenia złóż złota na mapę odległości od najbliższego uskoku
# Na mapę z ćwiczenia poprzedniego nałóż mapę rozmieszczenia złóż złota. Czy zauważasz jakąś zależność
# pomiędzy lokalizacją złóż złota a odległością od uskoków?

# %%
options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Wizualizacja mapy odległości
plot(faults_distmap, main = "Mapa odległości od najbliższego uskoku", xlab = "Współrzędna X", 
     ylab = "Współrzędna Y", col = topo.colors(20))

# Nałożenie złóż złota
plot(gold, add = TRUE, col = "gold")
# Out:
# Plot with title "Mapa odległości od najbliższego uskoku"

# %% [markdown]
# ##### Analiza zależności:
# Po nałożeniu mapy rozmieszczenia złóż złota na mapę odległości od uskoków, można wizualnie ocenić czy istnieje jakaś zależność pomiędzy lokalizacją złóż złota a odległością od uskoków.
# W przypadku, gdy złoża złota znajdują się w pobliżu uskoków, może to sugerować, że obecność uskoków wpływa na lokalizację złóż złota, na przykład ze względu na warunki geologiczne sprzyjające mineralizacji.

# %% [markdown]
# #### 5 Analiza względnego rozmieszczenia złóż złota względem uskoków
# Następnym krokiem będzie analiza względnego rozmieszczenia. Przedstaw wykres gęstości
# występowania złóż złota w zależności od odległości od uskoku. Zinterpretuj wykres.

# %%
# Użycie funkcji rhohat do analizy zależności gęstości złóż złota od odległości do uskoków
rho_result <- rhohat(gold, faults_distmap)

options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Wykres gęstości występowania złóż złota w zależności od odległości od uskoków
plot(rho_result, main = "Gęstość występowania złóż złota w zależności od odległości od uskoków",
     xlab = "Odległość od uskoku", ylab = "Gęstość", col = "blue")
# Out:
# Plot with title "Gęstość występowania złóż złota w zależności od odległości od uskoków"

# %% [markdown]
# ##### Interpretacja wykresu:
# Wykres przedstawia zależność gęstości występowania złóż złota od odległości od uskoków geologicznych. Na podstawie wykresu można zauważyć, że gęstość złóż złota jest najwyższa w bliskim sąsiedztwie uskoków i maleje wraz ze wzrostem odległości od nich. Wskazuje to na istotny związek między występowaniem złóż złota a bliskością do uskoków. Taki rozkład może sugerować, że uskoki geologiczne pełnią kluczową rolę w procesach tworzenia się złóż złota, prawdopodobnie działając jako kanały transportu lub miejsca depozycji złota. Malejąca gęstość na większych odległościach od uskoków potwierdza, że występowanie złóż złota jest bardziej skoncentrowane w ich pobliżu.

# %% [markdown]
# #### 6. Obliczenie mapy odległości od uskoków geologicznych
# Istnieje też inna wersja funkcji distmap, którą można wywołać używając funkcji `distfun`. Zwraca
# ona funkcję z argumentami` (x,y`) za pomocą której możemy oszacować odległości w dowolnej
# lokalizacji przestrzennej. Oblicz wartości tej funkcji dla całego obszaru.

# %%
# Utworzenie funkcji odległościowe
distance_function <- distfun(faults)

# Konwersja funkcji odległościowej na obraz pikselowy
distance_map  <- as.im(distance_function)

options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Wizualizacja mapy odległości
plot(distance_map , main = "Mapa odległości od uskoków geologicznych", 
     xlab = "Współrzędna X", ylab = "Współrzędna Y")
# Out:
# Plot with title "Mapa odległości od uskoków geologicznych"

# %% [markdown]
# #### 7. Obliczanie odległości do najbliższego uskoku w zadanym punkcie
# Oblicz odległość do najbliższego uskoku w punkcie o współrzędnych (400000,7000000).

# %%
# Definicja współrzędnych punktu
x_point <- 400000
y_point <- 7000000

# Obliczenie odległości do najbliższego uskoku od zadanego punktu
distance_to_fault <- distance_function(x_point, y_point)

# Wyświetlenie wyniku
cat("Odległość do najbliższego uskoku z punktu (400000, 7000000) wynosi:", distance_to_fault, "jednostek")
# Out:
# Odległość do najbliższego uskoku z punktu (400000, 7000000) wynosi: 18913.02 jednostek

# %% [markdown]
# #### 8. Mapa odległości od najbliższego uskoku i porównanie z mapą z zadania 3
# Wyświetl mapę wartości odległości punktów do najbliższego uskoku. Porównaj wynik z mapą
# uzyskaną w ćwiczeniu32.

# %%
options(repr.plot.width = 12, repr.plot.height = 8) # Ustawienie szerokości okna

# Ustawienie układu graficznego z dwoma wykresami obok siebie poziomo
par(mfrow = c(1, 2))

# Wizualizacja mapy odległości z zadania 3
plot(faults_distmap, main = "Mapa odległości od najbliższego uskoku - zadanie 3", xlab = "Współrzędna X", 
     ylab = "Współrzędna Y", col = topo.colors(20))

# Wizualizacja mapy odległości z zadania 8
plot(distance_map, main = "Mapa odległości od najbliższego uskoku - zadanie 8", xlab = "Współrzędna X", 
     ylab = "Współrzędna Y", col = topo.colors(20))
# Out:
# Plot with title "Mapa odległości od najbliższego uskoku - zadanie 8"
